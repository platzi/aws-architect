# %%
# Lab10: **Optimización de Funciones en AWS Lambda**

**Objetivos del Laboratorio**

- Crear y configurar una función Lambda.
- Probar la función.
- Modificar la configuración de memoria y CPU.
- Evaluar el impacto en el rendimiento.

**Instrucciones Detalladas**

**1. Iniciar sesión en la consola de AWS**

- Accede a la [Consola de administración de AWS](https://aws.amazon.com/console/) con tus credenciales.

**2. Crear una función Lambda**

1. En la consola de AWS, busca y selecciona **Lambda** en el menú de servicios.
2. Haz clic en **Crear función**.
3. Selecciona **Autor desde cero**.
4. Completa los siguientes campos:
    - **Nombre de la función**: Escribe un nombre descriptivo (por ejemplo, **`MiPrimeraFuncionLambda`**).
    - **Tiempo de ejecución**: Selecciona Python 3.x
    - **Rol**: Crea un nuevo rol que tenga permisos básicos para Lambda (puedes usar "Crear un nuevo rol con políticas básicas de Lambda").
5. Haz clic en **Crear función**.

**3. Escribir el código de la función**

1. En el editor de código, reemplaza el código predeterminado con el siguiente:

def `pythondef lambda_handler(event, context):
    return {
        'statusCode': 200,
        'body': '¡Hola desde Lambda!'
    }`

1. Haz clic en **Guardar** para guardar los cambios.

**4. Probar la función**

1. Haz clic en el botón **Probar** en la parte superior derecha.
2. Crea un evento de prueba:
    - Selecciona **Crear nuevo evento**.
    - Asigna un nombre al evento (por ejemplo, **`EventoPrueba`**).
    - Puedes dejar el contenido del evento vacío o agregar un JSON simple, como **`{}`**.
3. Haz clic en **Crear** y luego en **Probar** nuevamente para ejecutar la función.
4. Observa los resultados en la sección de salida para asegurarte de que funcione correctamente.

**5. Modificar la configuración de memoria y CPU**

**Cambiar memoria:**

1. En la consola de Lambda, selecciona tu función (**`MiPrimeraFuncionLambda`**).
2. Ve a la pestaña **Configuración**.
3. En la sección **Configuración general**, busca el campo **Memoria**.
4. Ajusta el valor entre 128 MB y 10,240 MB según tus necesidades (por ejemplo, prueba con 512 MB).
5. Haz clic en **Guardar** para aplicar los cambios.

**Impacto en CPU:**

- Ten en cuenta que al aumentar la memoria, también aumentas automáticamente la potencia de CPU disponible para tu función.

**6. Probar nuevamente la función**

1. Vuelve a hacer clic en **Probar**.
2. Ejecuta el mismo evento de prueba que creaste anteriormente.
3. Observa si hay mejoras en los tiempos de ejecución o cualquier otro cambio notable.

**7. Monitorear el rendimiento**

1. Ve a **CloudWatch Logs** desde la consola de AWS.
2. Busca los registros asociados a tu función Lambda (**`MiPrimeraFuncionLambda`**).
3. Revisa las métricas como duración y uso máximo de memoria para evaluar cómo los cambios afectan el rendimiento.

---

**Conclusiones del Laboratorio**

- Has creado una función Lambda básica y aprendido a modificar su configuración.
- Al aumentar la memoria, también aumentaste automáticamente la potencia de CPU disponible para tu función, lo que puede mejorar su rendimiento.
- La monitorización continua te ayudará a optimizar aún más tu función en el futuro.

Este laboratorio te proporciona una comprensión práctica sobre cómo funcionan las configuraciones en AWS Lambda y cómo puedes ajustar recursos para mejorar el rendimiento y optimizar costos.¡Disfruta experimentando con AWS Lambda!
